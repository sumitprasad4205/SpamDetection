# %%
import pandas as pd
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
df = pd.read_csv('spam.csv',encoding='latin-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df = df[['v1','v2']]
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.columns = ['label','text']
df
# Out:
#      label                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#Split Features and Labels
X = df['text']
Y = df['label']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=42)

# %%
lr_pipe = Pipeline([
    ('vectorizer',TfidfVectorizer(stop_words='english',max_df=0.7)),
    ('classifier',LogisticRegression(max_iter=1000))
])
lr_pipe
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(max_df=0.7, stop_words='english')),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %%
lr_pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(max_df=0.7, stop_words='english')),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %%
lr_score = lr_pipe.score(X_train,Y_train)
lr_score
# Out:
# 0.9699349338119811

# %%
lr_pred = lr_pipe.predict(X_test)

# %%
lr_accuracy = round(accuracy_score(Y_test,lr_pred),3)
lr_accuracy
# Out:
# 0.968

# %%
lr_cm = confusion_matrix(Y_test,lr_pred)
lr_cm_df = pd.DataFrame(lr_cm,index=['Actual Ham','Actual Spam'],columns=['Predicted Ham','Predicted Spam'])
lr_cm_df
# Out:
#              Predicted Ham  Predicted Spam
# Actual Ham             966               0
# Actual Spam             36             113

# %%
sns.heatmap(lr_cm_df,annot=True,fmt='d',cmap='viridis')
# Out:
# <Axes: >

# %%
lr_classification = classification_report(Y_test,lr_pred,output_dict=True)
lr_classification_df = pd.DataFrame(lr_classification)
lr_classification_df.transpose()
# Out:
#               precision    recall  f1-score      support
# ham            0.964072  1.000000  0.981707   966.000000
# spam           1.000000  0.758389  0.862595   149.000000
# accuracy       0.967713  0.967713  0.967713     0.967713
# macro avg      0.982036  0.879195  0.922151  1115.000000
# weighted avg   0.968873  0.967713  0.965790  1115.000000

# %%
Y_test.value_counts()
# Out:
# label
# ham     966
# spam    149
# Name: count, dtype: int64

# %%
rf_pipe = Pipeline([
    ('vectorizer',TfidfVectorizer(stop_words='english',max_df=0.7)),
    ('model',RandomForestClassifier(random_state=42))
])
rf_pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(max_df=0.7, stop_words='english')),
#                 ('model', RandomForestClassifier(random_state=42))])

# %%
rf_pred = rf_pipe.predict(X_test)

# %%
rf_accuracy = round(accuracy_score(Y_test,rf_pred),3)
rf_accuracy
# Out:
# 0.975

# %%
rf_cm = confusion_matrix(Y_test,rf_pred)
rf_cm_df = pd.DataFrame(rf_cm,index=['Actual Ham','Actual Spam'],columns=['Predicted Ham','Predicted Spam'])
rf_cm_df
# Out:
#              Predicted Ham  Predicted Spam
# Actual Ham             966               0
# Actual Spam             28             121

# %%
sns.heatmap(rf_cm_df,annot=True,fmt='d',cmap='viridis')
# Out:
# <Axes: >

# %%
rf_classification = classification_report(Y_test,rf_pred,output_dict=True)
rf_classification_df = pd.DataFrame(lr_classification)
rf_classification_df.transpose()
# Out:
#               precision    recall  f1-score      support
# ham            0.964072  1.000000  0.981707   966.000000
# spam           1.000000  0.758389  0.862595   149.000000
# accuracy       0.967713  0.967713  0.967713     0.967713
# macro avg      0.982036  0.879195  0.922151  1115.000000
# weighted avg   0.968873  0.967713  0.965790  1115.000000

# %%
mb_pipe = Pipeline([
    ('vectorizer',TfidfVectorizer(stop_words='english',max_df=0.7)),
    ('model',MultinomialNB())
])
mb_pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(max_df=0.7, stop_words='english')),
#                 ('model', MultinomialNB())])

# %%
mb_pred = mb_pipe.predict(X_test)

# %%
mb_accuracy = round(accuracy_score(Y_test,mb_pred),3)
mb_accuracy
# Out:
# 0.969

# %%
mb_cm = confusion_matrix(Y_test,mb_pred)
mb_cm_df = pd.DataFrame(mb_cm,index=['Actual Ham','Actual Spam'],columns=['Predicted Ham','Predicted Spam'])
mb_cm_df
# Out:
#              Predicted Ham  Predicted Spam
# Actual Ham             966               0
# Actual Spam             35             114

# %%
sns.heatmap(mb_cm_df,annot=True,fmt='d',cmap='viridis')
# Out:
# <Axes: >

# %%
mb_classification = classification_report(Y_test,mb_pred,output_dict=True)
mb_classification_df = pd.DataFrame(mb_classification)
mb_classification_df.transpose()
# Out:
#               precision    recall  f1-score     support
# ham            0.965035  1.000000  0.982206   966.00000
# spam           1.000000  0.765101  0.866920   149.00000
# accuracy       0.968610  0.968610  0.968610     0.96861
# macro avg      0.982517  0.882550  0.924563  1115.00000
# weighted avg   0.969707  0.968610  0.966800  1115.00000

# %%
Model = pd.DataFrame({
    'Model':['RandomForestClassifier','MultinomialNB','LogisticRegression'],
    "Accuracy":[rf_accuracy,mb_accuracy,lr_accuracy]
})
Model
# Out:
#                     Model  Accuracy
# 0  RandomForestClassifier     0.975
# 1           MultinomialNB     0.969
# 2      LogisticRegression     0.968

# %%
MODEL_FILE ='spam.pkl'
joblib.dump(rf_pipe,MODEL_FILE)
print('Model trained and Saved')
# Out:
# Model trained and Saved
